# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.covariance import GraphLassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import affinity_propagation
figsize(10,10)

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv('data/normal.csv')
abnormal_data = pd.read_csv('data/abnormal.csv')
data.columns = [s.strip()[2:] for s in data.columns]
abnormal_data.columns = [s.strip()[2:] for s in data.columns]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-5a4ce659fdf3> in <module>()
# ----> 1 data = pd.read_csv('data/normal.csv')
#       2 abnormal_data = pd.read_csv('data/abnormal.csv')
#       3 data.columns = [s.strip()[2:] for s in data.columns]
#       4 abnormal_data.columns = [s.strip()[2:] for s in data.columns]
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3218)()
#
# /Users/Alexandr/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5594)()
#
# IOError: File data/normal.csv does not exist

# %% [markdown]
# Normal data

# %%
X = data.copy()
# Replace values = -1e0 with Nan
X = X.where(X.values > -1e9)
X = X.dropna(axis=1, how='all')
X = X.dropna(axis=0)
# Reactive power
Y1 = X['30MKA01CE004'].copy()
# Active power
Y2 = X['30MKA01CE003'].copy()
# X = X.drop(['30MKA01CE004','30MKA01CE003', '\xd0\xb2\xd1\x80\xd0\xb5\xd0\xbc\xd1\x8f'], axis=1)
# Remove column with timestamp
X = X.drop(['\xd0\xb2\xd1\x80\xd0\xb5\xd0\xbc\xd1\x8f'], axis=1)

# %% [markdown]
# Abnormal data

# %%
X_test = abnormal_data.copy()
# Remove columns with Nan values
drop_cols = array(['MBL10CH001', 'MBV22CP001', '\xd1\x80\xd0\xb5\xd0\xbc\xd1\x8f'], dtype=object)
X_test = X_test.drop(drop_cols, axis=1)
X_test = X_test.where(X_test.values > -1e9)
X_test = X_test.dropna(axis=0)
# Reactive power
Y1_test = X_test['MKA01CE004'].copy()
# Active power
Y2_test = X_test['MKA01CE003'].copy()
# X_test = X_test.drop(['MKA01CE003', 'MKA01CE004'], axis=1)

# %% [markdown]
# # Correlation coefficients

# %%
cor = corrcoef(X.values.T)
matshow(cor)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10bc3d950>

# %% [markdown]
# # Normalizing data

# %%
ss = StandardScaler()
ss.fit_transform(X)
ss.transform(X_test)
# Out:
# array([[ 0.33520152, -2.41731125, -1.67643059, ..., -0.54265424,
#         -0.43125452, -2.30127468],
#        [ 0.33520152,  0.21913103, -1.70251776, ..., -0.00640047,
#         -0.03106217, -2.6491125 ],
#        [ 0.38566181,  0.15267925, -0.39719304, ...,  0.36026926,
#          0.32110709,  0.78710354],
#        ...,
#        [ 0.28838665,  0.3684265 , -0.41896951, ...,  0.34961521,
#          0.52600558,  0.15467114],
#        [ 0.28838665,  0.34346457, -0.41458449, ...,  0.33674512,
#          0.43956403,  0.13359006],
#        [-2.88965214, -0.33322818, -2.83801575, ...,  0.07127465,
#         -0.21675142, -0.10884236]])

# %% [markdown]
# # Sparse inverse covariance estimation

# %%
model = GraphLassoCV(max_iter=2000)
model.fit(X.values)
cov_ = model.covariance_
vmax = cov_.max()
plt.imshow(cov_, interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# Clustering features

# %%
_, labels = affinity_propagation(cov_)
print labels
# Out:
# [17 18  5 17  0  3  1  1  1  5 17 17 17 17 17 17 17 17 17  2 17 18 17  5  3
#   3  3  4  5  5  4  5  5  5 17  5  5  6 17 17 17 17  5  5  5  5  5 17  7  7
#   7  8  8  8  3  5  5 17 17 17 17  9  9  9 17  4  1 10 11 10 12  5 17 20  5
#  18 18 13 18 17 18 18 17 18  5 14 15 16 17 17 17 17 17 17 17 17 17 17 18 18
#  18 18 18 18 18 18 19 20 21  5 17 20 17 17 18 20 22  5 18 18 18 23 17]

# %%
cov_new = zeros((len(labels), len(labels)))
j = 0
for i in argsort(labels):
    cov_new[j] = cov_[i]
    j += 1
cov_new = cov_new.T
cov_n = zeros((len(labels), len(labels)))
j = 0
for i in argsort(labels):
    cov_n[j] = cov_new[i]
    j += 1
vmax=cov_n.max()
plt.imshow(cov_n.T, interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# Remove strongly correlated features 
rows = hstack((where(labels == 5)[0], where(labels == 17)[0]))
X1 = X.values[:, delete(range(123), rows)]
X1_test = X_test.values[:, delete(range(123), rows)]
print X1.shape, X.shape
# Out:
# (18634, 60) (18634, 123)

# %%
# Covariance matrix after removing strongly correlated features
model.fit(X1)
cov_ = model.covariance_
vmax = cov_.max()
plt.imshow(cov_, interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
plt.xticks(())
plt.yticks(())
print cov_
# Out:
# [[ 1.          0.06206215  0.29912465 ...,  0.3073832   0.30639865
#    0.05898351]
#  [ 0.06206215  1.          0.17378569 ...,  0.04639655  0.04634162
#    0.00940299]
#  [ 0.29912465  0.17378569  1.         ...,  0.23911032  0.2388903
#    0.04847362]
#  ...,
#  [ 0.3073832   0.04639655  0.23911032 ...,  1.          0.45080609
#    0.08484147]
#  [ 0.30639865  0.04634162  0.2388903  ...,  0.45080609  1.          0.08780863]
#  [ 0.05898351  0.00940299  0.04847362 ...,  0.08484147  0.08780863  1.        ]]

# %% [markdown]
# ## Predicting active power

# %%
# CV on a normal data
X_train, X_test, Y_train, Y_test = train_test_split(X1, Y2.values, train_size=0.9, random_state=7)
model = Ri()
model.fit(X_train, Y_train)
model.score(X_test, Y_test)
# Out:
# 0.9901032642409211

# %%
scatter(model.predict(X_test), Y_test)
plot([0, 160], [0, 160])

# %% [markdown]
# Abnormal data

# %%
model = LinearRegression()
model.fit(X1, Y2.values)
model.score(X1_test, Y2_test)
# Out:
# 0.93816507752771006

# %%
scatter(model.predict(X1_test), Y2_test)
plot([0,150], [0,150])
